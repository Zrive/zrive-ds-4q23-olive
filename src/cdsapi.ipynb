# %%
import cdsapi
import pandas as pd
from datetime import datetime

c = cdsapi.Client(url="https://cds.climate.copernicus.eu/api/v2", key="267758:1fe9aae3-582c-46cb-8b06-2ee01e3247ac")

# %%
start_date = datetime.strptime("01-01-2016", "%d-%m-%Y")
end_date = datetime.strptime("01-01-2022", "%d-%m-%Y")

# %%
import datetime

def get_days_of_month(month):
    year = datetime.datetime.now().year
    days = []
    for day in range(1, 32):
        try:
            date = datetime.datetime.strptime(f"{year}-{month}-{day:02}", "%Y-%m-%d")
            days.append(date.strftime("%d"))
        except ValueError:
            break
    return days


years = ["2016", "2017", "2018", "2019", "2020"]

months = [str(number).zfill(2) for number in range(1,13)]

# %%
for year in years:
    for month in months:

        days_month = get_days_of_month(month)

        c.retrieve(
            'reanalysis-era5-land',
            {
                'variable': [
                    'soil_temperature_level_1', 'total_precipitation', 'volumetric_soil_water_layer_1',
                ],
                'year': year,
                'month': month,
                'day': days_month,
                'time': [
                    '00:00', '01:00', '02:00',
                    '03:00', '04:00', '05:00',
                    '06:00', '07:00', '08:00',
                    '09:00', '10:00', '11:00',
                    '12:00', '13:00', '14:00',
                    '15:00', '16:00', '17:00',
                    '18:00', '19:00', '20:00',
                    '21:00', '22:00', '23:00',
                ],
                'area': [
                    39, -8, 35,
                    -1,
                ],
                'format': 'netcdf.zip',
            },
            f'SSM_LST_{month}_{year}.zip')
# Out:
# 2023-11-21 23:04:58,273 INFO Welcome to the CDS
# 2023-11-21 23:04:58,275 INFO Sending request to https://cds.climate.copernicus.eu/api/v2/resources/reanalysis-era5-land
# 2023-11-21 23:04:58,458 INFO Request is queued
# 2023-11-21 23:04:59,511 INFO Request is running
# 2023-11-21 23:11:17,322 INFO Request is completed
# 2023-11-21 23:11:17,323 INFO Downloading https://download-0013-clone.copernicus-climate.eu/cache-compute-0013/cache/data4/adaptor.mars.internal-1700608228.3305728-23620-1-2f0e4197-1124-4411-a0a8-a375982f18c8.zip to SSM_LST_01_2016.zip (6.2M)
# 2023-11-21 23:11:21,325 INFO Download rate 1.5M/s
# 2023-11-21 23:11:21,418 INFO Welcome to the CDS
# 2023-11-21 23:11:21,419 INFO Sending request to https://cds.climate.copernicus.eu/api/v2/resources/reanalysis-era5-land
# 2023-11-21 23:11:21,491 INFO Request is queued
# 2023-11-21 23:11:22,545 INFO Request is running
# 2023-11-21 23:17:40,194 INFO Request is completed
# 2023-11-21 23:17:40,195 INFO Downloading https://download-0018.copernicus-climate.eu/cache-compute-0018/cache/data8/adaptor.mars.internal-1700608606.9549158-22422-1-9a249b1c-779d-4936-a654-0a9ddd31b23b.zip to SSM_LST_02_2016.zip (5.6M)
# 2023-11-21 23:17:45,001 INFO Download rate 1.2M/s
# 2023-11-21 23:17:45,134 INFO Welcome to the CDS
# 2023-11-21 23:17:45,135 INFO Sending request to https://cds.climate.copernicus.eu/api/v2/resources/reanalysis-era5-land
# 2023-11-21 23:17:45,213 INFO Request is queued
# 2023-11-21 23:17:46,360 INFO Request is running
# 2023-11-21 23:24:04,141 INFO Request is completed
# 2023-11-21 23:24:04,142 INFO Downloading https://download-0011-clone.copernicus-climate.eu/cache-compute-0011/cache/data8/adaptor.mars.internal-1700608992.325714-8964-8-592f0a3e-1668-4b11-b878-ee8f18edbebd.zip to SSM_LST_03_2016.zip (5.8M)
# 2023-11-21 23:24:10,184 INFO Download rate 983.8K/s
# 2023-11-21 23:24:10,287 INFO Welcome to the CDS
# 2023-11-21 23:24:10,288 INFO Sending request to https://cds.climate.copernicus.eu/api/v2/resources/reanalysis-era5-land
# 2023-11-21 23:24:10,392 INFO Request is queued
# 2023-11-21 23:24:11,444 INFO Request is running
# 2023-11-21 23:30:29,211 INFO Request is completed
# 2023-11-21 23:30:29,212 INFO Downloading https://download-0008-clone.copernicus-climate.eu/cache-compute-0008/cache/data5/adaptor.mars.internal-1700609380.537416-23515-1-71c2a168-4295-41fe-8642-3642683bb120.zip to SSM_LST_04_2016.zip (5.9M)
# 2023-11-21 23:30:34,868 INFO Download rate 1M/s
# 2023-11-21 23:30:34,979 INFO Welcome to the CDS
# 2023-11-21 23:30:34,980 INFO Sending request to https://cds.climate.copernicus.eu/api/v2/resources/reanalysis-era5-land
# 2023-11-21 23:30:35,148 INFO Request is queued
# 2023-11-21 23:30:36,196 INFO Request is running
# 2023-11-21 23:36:54,355 INFO Request is completed
# 2023-11-21 23:36:54,357 INFO Downloading https://download-0007-clone.copernicus-climate.eu/cache-compute-0007/cache/data7/adaptor.mars.internal-1700609764.5911386-29482-16-712db5a8-72ea-4c04-9f81-754b200cd122.zip to SSM_LST_05_2016.zip (5.9M)
# 2023-11-21 23:36:59,545 INFO Download rate 1.1M/s
# 2023-11-21 23:36:59,663 INFO Welcome to the CDS
# 2023-11-21 23:36:59,665 INFO Sending request to https://cds.climate.copernicus.eu/api/v2/resources/reanalysis-era5-land
# 2023-11-21 23:36:59,721 INFO Request is queued
# 2023-11-21 23:37:00,772 INFO Request is running
# 2023-11-21 23:43:19,090 INFO Request is completed
# 2023-11-21 23:43:19,091 INFO Downloading https://download-0007-clone.copernicus-climate.eu/cache-compute-0007/cache/data7/adaptor.mars.internal-1700610142.428373-23871-16-62d6e40f-ed87-4b43-ab10-00d29fa2bef1.zip to SSM_LST_06_2016.zip (5M)
# 2023-11-21 23:43:24,839 INFO Download rate 882.7K/s
# 2023-11-21 23:43:25,003 INFO Welcome to the CDS
# 2023-11-21 23:43:25,008 INFO Sending request to https://cds.climate.copernicus.eu/api/v2/resources/reanalysis-era5-land
# 2023-11-21 23:43:25,165 INFO Request is queued
# 2023-11-21 23:43:26,234 INFO Request is running
# 2023-11-21 23:49:44,337 INFO Request is completed
# 2023-11-21 23:49:44,338 INFO Downloading https://download-0002-clone.copernicus-climate.eu/cache-compute-0002/cache/data5/adaptor.mars.internal-1700610553.5215745-30259-14-3d7ae7ab-a1a1-47fb-8f4b-6a6f73d35b97.zip to SSM_LST_07_2016.zip (5M)
# 2023-11-21 23:49:48,203 INFO Download rate 1.3M/s
# 2023-11-21 23:49:48,314 INFO Welcome to the CDS
# 2023-11-21 23:49:48,315 INFO Sending request to https://cds.climate.copernicus.eu/api/v2/resources/reanalysis-era5-land
# 2023-11-21 23:49:48,400 INFO Request is queued
# 2023-11-21 23:49:49,532 INFO Request is running
# 2023-11-21 23:56:07,312 INFO Request is completed
# 2023-11-21 23:56:07,318 INFO Downloading https://download-0002-clone.copernicus-climate.eu/cache-compute-0002/cache/data5/adaptor.mars.internal-1700610917.0781279-366-9-8e7aabd3-3315-4fdb-92e8-7de37766f3d2.zip to SSM_LST_08_2016.zip (4.8M)
# 2023-11-21 23:56:14,759 INFO Download rate 654.2K/s
# 2023-11-21 23:56:14,857 INFO Welcome to the CDS
# 2023-11-21 23:56:14,859 INFO Sending request to https://cds.climate.copernicus.eu/api/v2/resources/reanalysis-era5-land
# 2023-11-21 23:56:14,941 INFO Request is queued
# 2023-11-21 23:56:15,986 INFO Request is running
# 2023-11-22 00:02:33,800 INFO Request is completed
# 2023-11-22 00:02:33,802 INFO Downloading https://download-0011-clone.copernicus-climate.eu/cache-compute-0011/cache/data6/adaptor.mars.internal-1700611325.3572698-25063-15-b656dcc3-f344-4da1-9b7d-b04e6b7d2a86.zip to SSM_LST_09_2016.zip (4.8M)
# 2023-11-22 00:02:37,985 INFO Download rate 1.2M/s
# 2023-11-22 00:02:38,110 INFO Welcome to the CDS
# 2023-11-22 00:02:38,113 INFO Sending request to https://cds.climate.copernicus.eu/api/v2/resources/reanalysis-era5-land
# 2023-11-22 00:02:38,194 INFO Request is queued
# 2023-11-22 00:02:43,104 INFO Request is running
# 2023-11-22 00:08:57,022 INFO Request is completed
# 2023-11-22 00:08:57,023 INFO Downloading https://download-0021.copernicus-climate.eu/cache-compute-0021/cache/data7/adaptor.mars.internal-1700611682.4009933-18199-8-239a802d-94e9-4532-a02a-33700dd28477.zip to SSM_LST_10_2016.zip (5.6M)
# 2023-11-22 00:09:01,949 INFO Download rate 1.1M/s
# 2023-11-22 00:09:02,238 INFO Welcome to the CDS
# 2023-11-22 00:09:02,239 INFO Sending request to https://cds.climate.copernicus.eu/api/v2/resources/reanalysis-era5-land
# 2023-11-22 00:09:02,343 INFO Request is queued
# 2023-11-22 00:09:03,424 INFO Request is running
# 2023-11-22 00:15:23,730 INFO Request is completed
# 2023-11-22 00:15:23,731 INFO Downloading https://download-0000-clone.copernicus-climate.eu/cache-compute-0000/cache/data1/adaptor.mars.internal-1700612064.8952727-19801-9-dcc15ce3-9f85-446d-8dec-440295968e81.zip to SSM_LST_11_2016.zip (5.8M)
# 2023-11-22 00:15:28,287 INFO Download rate 1.3M/s
# 2023-11-22 00:15:28,457 INFO Welcome to the CDS
# 2023-11-22 00:15:28,464 INFO Sending request to https://cds.climate.copernicus.eu/api/v2/resources/reanalysis-era5-land
# 2023-11-22 00:15:28,544 INFO Request is queued
# 2023-11-22 00:15:29,597 INFO Request is running
# 2023-11-22 00:21:47,473 INFO Request is completed
# 2023-11-22 00:21:47,481 INFO Downloading https://download-0008-clone.copernicus-climate.eu/cache-compute-0008/cache/data1/adaptor.mars.internal-1700612463.7831204-14443-12-63b7bf24-c16f-403e-871f-619721661795.zip to SSM_LST_12_2016.zip (6M)
# 2023-11-22 00:21:52,472 INFO Download rate 1.2M/s
# 2023-11-22 00:21:52,719 INFO Welcome to the CDS
# 2023-11-22 00:21:52,720 INFO Sending request to https://cds.climate.copernicus.eu/api/v2/resources/reanalysis-era5-land
# 2023-11-22 00:21:52,822 INFO Request is queued
# 2023-11-22 00:21:53,874 INFO Request is running
# 2023-11-22 00:28:11,622 INFO Request is completed
# 2023-11-22 00:28:11,623 INFO Downloading https://download-0002-clone.copernicus-climate.eu/cache-compute-0002/cache/data5/adaptor.mars.internal-1700612853.0140839-19203-6-b7471eed-c723-4132-ab2c-c4cf735cb38e.zip to SSM_LST_01_2017.zip (5.7M)
# 2023-11-22 00:28:17,954 INFO Download rate 920.5K/s
# 2023-11-22 00:28:18,063 INFO Welcome to the CDS
# 2023-11-22 00:28:18,070 INFO Sending request to https://cds.climate.copernicus.eu/api/v2/resources/reanalysis-era5-land
# 2023-11-22 00:28:18,145 INFO Request is queued
# 2023-11-22 00:28:23,057 INFO Request is running
# 2023-11-22 00:34:36,908 INFO Request is completed
# 2023-11-22 00:34:36,919 INFO Downloading https://download-0013-clone.copernicus-climate.eu/cache-compute-0013/cache/data5/adaptor.mars.internal-1700613206.3058734-30390-15-6984210f-4039-4d98-bfa6-82f538193aba.zip to SSM_LST_02_2017.zip (5.5M)
# 2023-11-22 00:34:42,134 INFO Download rate 1.1M/s
# 2023-11-22 00:34:42,248 INFO Welcome to the CDS
# 2023-11-22 00:34:42,249 INFO Sending request to https://cds.climate.copernicus.eu/api/v2/resources/reanalysis-era5-land
# 2023-11-22 00:34:42,357 INFO Request is queued
# 2023-11-22 00:34:43,411 INFO Request is running
# 2023-11-22 00:41:01,156 INFO Request is completed
# 2023-11-22 00:41:01,157 INFO Downloading https://download-0014-clone.copernicus-climate.eu/cache-compute-0014/cache/data0/adaptor.mars.internal-1700613620.4112785-13822-4-f980b5b7-dfa0-4faf-a28a-eae98bf57b04.zip to SSM_LST_03_2017.zip (5.8M)
# 2023-11-22 00:41:02,468 INFO Download rate 4.4M/s
# 2023-11-22 00:41:02,576 INFO Welcome to the CDS
# 2023-11-22 00:41:02,577 INFO Sending request to https://cds.climate.copernicus.eu/api/v2/resources/reanalysis-era5-land
# 2023-11-22 00:41:02,788 INFO Request is queued
# 2023-11-22 00:41:03,839 INFO Request is running
# 2023-11-22 00:47:25,145 INFO Request is completed
# 2023-11-22 00:47:25,307 INFO Downloading https://download-0006-clone.copernicus-climate.eu/cache-compute-0006/cache/data4/adaptor.mars.internal-1700613979.234041-19655-10-5c58bf63-e4ab-4291-b16b-8e1303d338b8.zip to SSM_LST_04_2017.zip (5.4M)
# 2023-11-22 00:47:26,646 INFO Download rate 4.1M/s
# 2023-11-22 00:47:26,790 INFO Welcome to the CDS
# 2023-11-22 00:47:26,793 INFO Sending request to https://cds.climate.copernicus.eu/api/v2/resources/reanalysis-era5-land
# 2023-11-22 00:47:26,872 INFO Request is queued
# 2023-11-22 00:47:27,930 INFO Request is running
# 2023-11-22 00:53:46,021 INFO Request is completed
# 2023-11-22 00:53:46,056 INFO Downloading https://download-0009-clone.copernicus-climate.eu/cache-compute-0009/cache/data4/adaptor.mars.internal-1700614390.7056122-27754-8-0cb83554-49d3-4033-8087-32056888c016.zip to SSM_LST_05_2017.zip (5.6M)
# 2023-11-22 00:53:50,269 INFO Download rate 1.3M/s
# 2023-11-22 00:53:50,385 INFO Welcome to the CDS
# 2023-11-22 00:53:50,386 INFO Sending request to https://cds.climate.copernicus.eu/api/v2/resources/reanalysis-era5-land
# 2023-11-22 00:53:50,499 INFO Request is queued
# 2023-11-22 00:53:51,557 INFO Request is running
# 2023-11-22 01:00:10,355 INFO Request is completed
# 2023-11-22 01:00:10,381 INFO Downloading https://download-0009-clone.copernicus-climate.eu/cache-compute-0009/cache/data5/adaptor.mars.internal-1700614774.568741-10567-2-853a626d-a296-4014-a4f1-83e54b368ed0.zip to SSM_LST_06_2017.zip (5M)
# 2023-11-22 01:00:12,976 INFO Download rate 1.9M/s
# 2023-11-22 01:00:13,078 INFO Welcome to the CDS
# 2023-11-22 01:00:13,079 INFO Sending request to https://cds.climate.copernicus.eu/api/v2/resources/reanalysis-era5-land
# 2023-11-22 01:00:13,147 INFO Request is queued
# 2023-11-22 01:00:21,467 INFO Request is running
# 2023-11-22 01:06:31,829 INFO Request is completed
# 2023-11-22 01:06:31,833 INFO Downloading https://download-0015-clone.copernicus-climate.eu/cache-compute-0015/cache/data5/adaptor.mars.internal-1700615156.344767-15457-2-60210606-84a7-40b1-ab68-3403703a7610.zip to SSM_LST_07_2017.zip (4.9M)
# 2023-11-22 01:06:35,039 INFO Download rate 1.5M/s
# 2023-11-22 01:06:35,152 INFO Welcome to the CDS
# 2023-11-22 01:06:35,153 INFO Sending request to https://cds.climate.copernicus.eu/api/v2/resources/reanalysis-era5-land
# 2023-11-22 01:06:35,315 INFO Request is queued
# 2023-11-22 01:06:36,366 INFO Request is running
# 2023-11-22 01:14:54,665 INFO Request is completed
# 2023-11-22 01:14:54,667 INFO Downloading https://download-0018.copernicus-climate.eu/cache-compute-0018/cache/data5/adaptor.mars.internal-1700615592.2094245-5667-12-f9b9fb76-3f7e-40cf-894d-ffa191d83e7a.zip to SSM_LST_08_2017.zip (4.8M)
# 2023-11-22 01:14:57,309 INFO Download rate 1.8M/s
# 2023-11-22 01:14:57,429 INFO Welcome to the CDS
# 2023-11-22 01:14:57,430 INFO Sending request to https://cds.climate.copernicus.eu/api/v2/resources/reanalysis-era5-land
# 2023-11-22 01:14:57,523 INFO Request is queued
# 2023-11-22 01:14:58,573 INFO Request is running
# 2023-11-22 01:21:16,425 INFO Request is completed
# 2023-11-22 01:21:16,427 INFO Downloading https://download-0017.copernicus-climate.eu/cache-compute-0017/cache/data4/adaptor.mars.internal-1700616024.1415117-9554-7-7ddaaccf-3fb8-4e36-accd-d3a200f4260c.zip to SSM_LST_09_2017.zip (4.8M)
# 2023-11-22 01:21:20,086 INFO Download rate 1.3M/s
# 2023-11-22 01:21:20,195 INFO Welcome to the CDS
# 2023-11-22 01:21:20,197 INFO Sending request to https://cds.climate.copernicus.eu/api/v2/resources/reanalysis-era5-land
# 2023-11-22 01:21:20,310 INFO Request is queued
# 2023-11-22 01:21:33,774 INFO Request is running
# 2023-11-22 01:27:39,107 INFO Request is completed
# 2023-11-22 01:27:39,108 INFO Downloading https://download-0016.copernicus-climate.eu/cache-compute-0016/cache/data2/adaptor.mars.internal-1700616449.4765759-10927-7-738a3ccd-7e96-4dff-8f17-6d2c35e93c61.zip to SSM_LST_10_2017.zip (5.1M)
# 2023-11-22 01:27:42,232 INFO Download rate 1.6M/s
# 2023-11-22 01:27:42,335 INFO Welcome to the CDS
# 2023-11-22 01:27:42,337 INFO Sending request to https://cds.climate.copernicus.eu/api/v2/resources/reanalysis-era5-land
# 2023-11-22 01:27:42,417 INFO Request is queued
# 2023-11-22 01:27:50,760 INFO Request is running
# 2023-11-22 01:34:01,122 INFO Request is completed
# 2023-11-22 01:34:01,124 INFO Downloading https://download-0020.copernicus-climate.eu/cache-compute-0020/cache/data0/adaptor.mars.internal-1700616789.4467006-3140-17-c31999b1-dbfc-4b08-b9dc-c99dd53fd80f.zip to SSM_LST_11_2017.zip (5.3M)
# 2023-11-22 01:34:04,333 INFO Download rate 1.6M/s
# 2023-11-22 01:34:04,447 INFO Welcome to the CDS
# 2023-11-22 01:34:04,449 INFO Sending request to https://cds.climate.copernicus.eu/api/v2/resources/reanalysis-era5-land
# 2023-11-22 01:34:04,540 INFO Request is queued
# 2023-11-22 01:34:05,592 INFO Request is running
# 2023-11-22 01:40:23,386 INFO Request is completed
# 2023-11-22 01:40:23,388 INFO Downloading https://download-0000-clone.copernicus-climate.eu/cache-compute-0000/cache/data7/adaptor.mars.internal-1700617183.0239863-31098-15-8944598e-b495-4554-a972-064d6630f666.zip to SSM_LST_12_2017.zip (5.8M)
# 2023-11-22 01:40:26,567 INFO Download rate 1.8M/s
# 2023-11-22 01:40:26,676 INFO Welcome to the CDS
# 2023-11-22 01:40:26,678 INFO Sending request to https://cds.climate.copernicus.eu/api/v2/resources/reanalysis-era5-land
# 2023-11-22 01:40:26,752 INFO Request is queued
# 2023-11-22 01:40:27,814 INFO Request is running
# 2023-11-22 01:46:45,536 INFO Request is completed
# 2023-11-22 01:46:45,537 INFO Downloading https://download-0013-clone.copernicus-climate.eu/cache-compute-0013/cache/data7/adaptor.mars.internal-1700617550.50354-14446-5-1b6e4a80-a7b5-4f19-ae05-90b7d59726ec.zip to SSM_LST_01_2018.zip (5.9M)
# 2023-11-22 01:46:48,248 INFO Download rate 2.2M/s
# 2023-11-22 01:46:48,359 INFO Welcome to the CDS
# 2023-11-22 01:46:48,362 INFO Sending request to https://cds.climate.copernicus.eu/api/v2/resources/reanalysis-era5-land
# 2023-11-22 01:46:48,431 INFO Request is queued
# 2023-11-22 01:46:49,478 INFO Request is running
# 2023-11-22 01:53:07,154 INFO Request is completed
# 2023-11-22 01:53:07,156 INFO Downloading https://download-0013-clone.copernicus-climate.eu/cache-compute-0013/cache/data0/adaptor.mars.internal-1700617908.2565536-18612-6-586f5fb6-71e5-4f39-8d0d-3e87e7037288.zip to SSM_LST_02_2018.zip (5.3M)
# 2023-11-22 01:53:09,795 INFO Download rate 2M/s
# 2023-11-22 01:53:09,913 INFO Welcome to the CDS
# 2023-11-22 01:53:09,915 INFO Sending request to https://cds.climate.copernicus.eu/api/v2/resources/reanalysis-era5-land
# 2023-11-22 01:53:09,970 INFO Request is queued
# 2023-11-22 01:53:11,032 INFO Request is running
# 2023-11-22 01:59:28,811 INFO Request is completed
# 2023-11-22 01:59:28,812 INFO Downloading https://download-0006-clone.copernicus-climate.eu/cache-compute-0006/cache/data3/adaptor.mars.internal-1700618325.6509602-23332-11-2e7ba3f8-6944-4206-bbc5-802414f91192.zip to SSM_LST_03_2018.zip (6.5M)
# 2023-11-22 01:59:32,417 INFO Download rate 1.8M/s
# 2023-11-22 01:59:32,536 INFO Welcome to the CDS
# 2023-11-22 01:59:32,537 INFO Sending request to https://cds.climate.copernicus.eu/api/v2/resources/reanalysis-era5-land
# 2023-11-22 01:59:32,624 INFO Request is queued
# 2023-11-22 01:59:33,681 INFO Request is running
# 2023-11-22 02:05:51,423 INFO Request is completed
# 2023-11-22 02:05:51,431 INFO Downloading https://download-0005-clone.copernicus-climate.eu/cache-compute-0005/cache/data5/adaptor.mars.internal-1700618711.0582552-28589-13-cac076c0-cf03-4ed5-991a-d3a253862afa.zip to SSM_LST_04_2018.zip (5.9M)
# 2023-11-22 02:05:54,977 INFO Download rate 1.7M/s
# 2023-11-22 02:05:55,088 INFO Welcome to the CDS
# 2023-11-22 02:05:55,089 INFO Sending request to https://cds.climate.copernicus.eu/api/v2/resources/reanalysis-era5-land
# 2023-11-22 02:05:55,171 INFO Request is queued
# 2023-11-22 02:05:56,219 INFO Request is running
